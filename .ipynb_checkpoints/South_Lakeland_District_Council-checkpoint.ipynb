# %% [markdown]
# # South Lakeland District Council Business Rates

# %% [markdown]
# Full list of non-domestic properties in South Lakeland, Business Rates list showing the rateable value, any reliefs, annual charge and the properties occupied status.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sldc.csv')

# %%
df.head()
# Out:
#   EffectiveDate            OrganisationNameLabel  \
# 0    07/05/2020  South Lakeland District Council
# 1    07/05/2020  South Lakeland District Council
# 2    07/05/2020  South Lakeland District Council
# 3    07/05/2020  South Lakeland District Council
# 4    07/05/2020  South Lakeland District Council
#
#                                      OrganisationURI  \
# 0  http://opendatacommunities.org/id/district-cou...
# 1  http://opendatacommunities.org/id/district-cou...
# 2  http://opendatacommunities.org/id/district-cou...
# 3  http://opendatacommunities.org/id/district-cou...
# 4  http://opendatacommunities.org/id/district-cou...
#
#                ServiceCategoryLabel               ServiceCategoryURI  \
# 0  Business rates account enquiries  http://id.esd.org.uk/service/56
# 1  Business rates account enquiries  http://id.esd.org.uk/service/56
# 2  Business rates account enquiries  http://id.esd.org.uk/service/56
# ...

# %%
df.shape
# Out:
# (8812, 40)

# %%
df.columns
# Out:
# Index(['EffectiveDate', 'OrganisationNameLabel', 'OrganisationURI',
#        'ServiceCategoryLabel', 'ServiceCategoryURI', 'Licence', 'AccountName',
#        'PropertyName1', 'PropertyName2', 'PropertyAddress1',
#        'PropertyAddress2', 'PropertyAddress3', 'PropertyAddress4',
#        'PropertyPostCode', 'CurrentRateableValue   ', 'MandatoryReliefAmount',
#        'DiscretionaryReliefDAmount', 'TransitionalReliefAmount ',
#        'TranstionalPremiumAmount ', 'SmallBusinessRatesReliefAmount',
#        'NetLocalDiscountAmount ', 'RetailDiscount ', 'ChargedAmount', 'Empty',
#        'EmptyFromDate               ', 'Exempt',
#        'PropertyReference           ', 'DateLiableFrom              ',
#        'RateablePropertyType',
#        'ValuationOfficePropertyDescription                                      ',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
# ...

# %%
new_df=df.iloc[:,0:30]
new_df.head()
# Out:
#   EffectiveDate            OrganisationNameLabel  \
# 0    07/05/2020  South Lakeland District Council
# 1    07/05/2020  South Lakeland District Council
# 2    07/05/2020  South Lakeland District Council
# 3    07/05/2020  South Lakeland District Council
# 4    07/05/2020  South Lakeland District Council
#
#                                      OrganisationURI  \
# 0  http://opendatacommunities.org/id/district-cou...
# 1  http://opendatacommunities.org/id/district-cou...
# 2  http://opendatacommunities.org/id/district-cou...
# 3  http://opendatacommunities.org/id/district-cou...
# 4  http://opendatacommunities.org/id/district-cou...
#
#                ServiceCategoryLabel               ServiceCategoryURI  \
# 0  Business rates account enquiries  http://id.esd.org.uk/service/56
# 1  Business rates account enquiries  http://id.esd.org.uk/service/56
# 2  Business rates account enquiries  http://id.esd.org.uk/service/56
# ...

# %%
new_df.shape
# Out:
# (8812, 30)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8812 entries, 0 to 8811
# Data columns (total 30 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   EffectiveDate                                                             8585 non-null   object
#  1   OrganisationNameLabel                                                     8585 non-null   object
#  2   OrganisationURI                                                           8585 non-null   object
#  3   ServiceCategoryLabel                                                      8585 non-null   object
#  4   ServiceCategoryURI                                                        8585 non-null   object
#  5   Licence                                                                   8585 non-null   object
# ...

# %%
new_df['EffectiveDate'].value_counts()
# Out:
# 07/05/2020    8585
# Name: EffectiveDate, dtype: int64

# %%
new_df.iloc[:,27]=pd.to_datetime(new_df.iloc[:,27])
new_df.iloc[:,0]=pd.to_datetime(new_df.iloc[:,0])
new_df.iloc[:,24]=pd.to_datetime(new_df.iloc[:,24])
new_df.head()
# Out:
#   EffectiveDate            OrganisationNameLabel  \
# 0    2020-07-05  South Lakeland District Council
# 1    2020-07-05  South Lakeland District Council
# 2    2020-07-05  South Lakeland District Council
# 3    2020-07-05  South Lakeland District Council
# 4    2020-07-05  South Lakeland District Council
#
#                                      OrganisationURI  \
# 0  http://opendatacommunities.org/id/district-cou...
# 1  http://opendatacommunities.org/id/district-cou...
# 2  http://opendatacommunities.org/id/district-cou...
# 3  http://opendatacommunities.org/id/district-cou...
# 4  http://opendatacommunities.org/id/district-cou...
#
#                ServiceCategoryLabel               ServiceCategoryURI  \
# 0  Business rates account enquiries  http://id.esd.org.uk/service/56
# 1  Business rates account enquiries  http://id.esd.org.uk/service/56
# 2  Business rates account enquiries  http://id.esd.org.uk/service/56
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8812 entries, 0 to 8811
# Data columns (total 30 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   EffectiveDate                                                             8585 non-null   datetime64[ns]
#  1   OrganisationNameLabel                                                     8585 non-null   object
#  2   OrganisationURI                                                           8585 non-null   object
#  3   ServiceCategoryLabel                                                      8585 non-null   object
#  4   ServiceCategoryURI                                                        8585 non-null   object
#  5   Licence                                                                   8585 non-null   object
# ...

# %%
new_df.iloc[:,13].value_counts()
# Out:
# LA12 7LQ    86
# LA9 4LR     79
# LA9 4BH     55
# LA9 6NZ     55
# LA9 4HE     47
#             ..
# LA12 8LP     1
# LA9 7HF      1
# LA6 2QG      1
# LA6 1NT      1
# LA9 4SF      1
# Name: PropertyPostCode, Length: 2195, dtype: int64

# %% [markdown]
# # Insight 1:
# Top 4 localities:
#
# LA12 7LQ    86
#
# LA9 4LR     79
#
# LA9 6NZ     55
#
# LA9 4BH     55

# %%
new_df.iloc[:,29].value_counts()
# Out:
# SELF CATERING HOLIDAY UNIT AND PREMISES                         1943
# SHOP AND PREMISES                                               1117
# OFFICES AND PREMISES                                             635
# WORKSHOP AND PREMISES                                            601
# STORE AND PREMISES                                               287
#                                                                 ...
# DINGHY PARK AND PREMISES                                           1
# BIKE SHOWROOM AND PREMISES                                         1
# AUCTION ROOMS AND PREMISES                                         1
# COMMUNITY HALL AND PREMISES                                        1
# KIOSK                                                              1
# Name: ValuationOfficePropertyDescription                                      , Length: 631, dtype: int64

# %% [markdown]
# # Insight 2:
# These are the top three types of properties:
#
# -SELF CATERING HOLIDAY UNIT AND PREMISES(1943)
#
# -SHOP AND PREMISES(1117)
#
# -OFFICES AND PREMISES(635)

# %%
new_df['Year']=new_df.iloc[:,27].dt.year

# %%
new_df.head()
# Out:
#   EffectiveDate            OrganisationNameLabel  \
# 0    2020-07-05  South Lakeland District Council
# 1    2020-07-05  South Lakeland District Council
# 2    2020-07-05  South Lakeland District Council
# 3    2020-07-05  South Lakeland District Council
# 4    2020-07-05  South Lakeland District Council
#
#                                      OrganisationURI  \
# 0  http://opendatacommunities.org/id/district-cou...
# 1  http://opendatacommunities.org/id/district-cou...
# 2  http://opendatacommunities.org/id/district-cou...
# 3  http://opendatacommunities.org/id/district-cou...
# 4  http://opendatacommunities.org/id/district-cou...
#
#                ServiceCategoryLabel               ServiceCategoryURI  \
# 0  Business rates account enquiries  http://id.esd.org.uk/service/56
# 1  Business rates account enquiries  http://id.esd.org.uk/service/56
# 2  Business rates account enquiries  http://id.esd.org.uk/service/56
# ...

# %%
new_df['AccountName'].value_counts()
# Out:
# S L D C                                                             67
# CUMBRIA COUNTY COUNCIL CLIENT   SERVICES                            64
# THE NATIONAL TRUST                                                  44
# UNITED UTILITIES WATER PLC                                          31
# VODAFONE LTD                                                        26
#                                                                     ..
# THE BODY SHOP INTERNATIONAL LTD                                      1
# CARPETRIGHT PLC                                                      1
# THE JOINERY MILL LTD                                                 1
# M E SAUNDERS & SONS LTD                                              1
# STARS PUBS & BARS LTD                                                1
# Name: AccountName, Length: 2878, dtype: int64

# %% [markdown]
# # Insight 3:
# These are the top three account holders of the properties:
#
# 1. S L D C(67)
# 2. CUMBRIA COUNTY COUNCIL CLIENT SERVICES(64)
# 3. THE NATIONAL TRUST(44)

# %%
new_df['Year'].value_counts()
# Out:
# 2010.0    3391
# 2017.0     851
# 2019.0     734
# 2018.0     734
# 2015.0     673
# 2016.0     580
# 2014.0     438
# 2013.0     342
# 2012.0     326
# 2011.0     318
# 2020.0     198
# Name: Year, dtype: int64

# %% [markdown]
# # Insight 4:
# 1. 3391 properties are available from 2010.
# 2. 198 new properties are liable from 2020.

# %%
new_df['Empty'].value_counts()
# Out:
# N         8187
# Y          398
# Name: Empty, dtype: int64

# %% [markdown]
# # Insight 5:
# There are 398 empty properties as of now.
